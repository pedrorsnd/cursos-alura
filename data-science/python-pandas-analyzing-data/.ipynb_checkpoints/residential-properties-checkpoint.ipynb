# %% [markdown]
# # Report Analyze III

# %% [markdown]
# ## Residential Properties

# %%
import pandas as pd

# %%
data = pd.read_csv('files/aluguel.csv', sep = ';')
data.head(10)
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
# 5              Apartamento     Vista Alegre        3      1       0    70
# 6              Apartamento         Cachambi        2      0       0    50
# 7       Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 8       Casa de Condomínio            Ramos        2      2       0    65
# 9  Conjunto Comercial/Sala           Centro        0      3       0   695
#
#      Valor  Condominio    IPTU
# 0   1700.0       500.0    60.0
# 1   7000.0         NaN     NaN
# 2   5200.0      4020.0  1111.0
# ...

# %%
list_residentials = list(data['Tipo'].drop_duplicates())
list_residentials
# Out:
# ['Quitinete',
#  'Casa',
#  'Conjunto Comercial/Sala',
#  'Apartamento',
#  'Casa de Condomínio',
#  'Prédio Inteiro',
#  'Flat',
#  'Loja/Salão',
#  'Galpão/Depósito/Armazém',
#  'Casa Comercial',
#  'Casa de Vila',
#  'Terreno Padrão',
#  'Box/Garagem',
#  'Loft',
#  'Loja Shopping/ Ct Comercial',
#  'Chácara',
#  'Loteamento/Condomínio',
#  'Sítio',
#  'Pousada/Chalé',
#  'Studio',
#  'Hotel',
#  'Indústria']

# %%
list_residentials = ['Quitinete',
                     'Casa',
                     'Apartamento',
                     'Casa de Condomínio', 
                     'Casa de Vila']

list_residentials
# Out:
# ['Quitinete', 'Casa', 'Apartamento', 'Casa de Condomínio', 'Casa de Vila']

# %%
data.head(10)
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
# 5              Apartamento     Vista Alegre        3      1       0    70
# 6              Apartamento         Cachambi        2      0       0    50
# 7       Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 8       Casa de Condomínio            Ramos        2      2       0    65
# 9  Conjunto Comercial/Sala           Centro        0      3       0   695
#
#      Valor  Condominio    IPTU
# 0   1700.0       500.0    60.0
# 1   7000.0         NaN     NaN
# 2   5200.0      4020.0  1111.0
# ...

# %%
selected_residentials = data['Tipo'].isin(list_residentials)
selected_residentials
# Out:
# 0         True
# 1         True
# 2        False
# 3         True
# 4         True
#          ...
# 32955     True
# 32956     True
# 32957     True
# 32958     True
# 32959    False
# Name: Tipo, Length: 32960, dtype: bool

# %%
select_residentials = data[selected_residentials]
select_residentials
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 3      Apartamento                Centro        1      0       0    15
# 4      Apartamento          Higienópolis        1      0       0    48
# 5      Apartamento          Vista Alegre        3      1       0    70
# ...            ...                   ...      ...    ...     ...   ...
# 32953  Apartamento                 Méier        2      0       0    70
# 32955    Quitinete                Centro        0      0       0    27
# 32956  Apartamento           Jacarepaguá        3      1       2    78
# 32957  Apartamento  São Francisco Xavier        2      1       0    48
# 32958  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 0      1700.0       500.0  60.0
# 1      7000.0         NaN   NaN
# ...

# %%
print(list(select_residentials['Tipo'].drop_duplicates()))
# Out:
# ['Quitinete', 'Casa', 'Apartamento', 'Casa de Condomínio', 'Casa de Vila']

# %%
print(select_residentials.shape[0], data.shape[0])
# Out:
# 22580 32960

# %%
select_residentials.index = range(select_residentials.shape[0])
select_residentials
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento          Vista Alegre        3      1       0    70
# ...            ...                   ...      ...    ...     ...   ...
# 22575  Apartamento                 Méier        2      0       0    70
# 22576    Quitinete                Centro        0      0       0    27
# 22577  Apartamento           Jacarepaguá        3      1       2    78
# 22578  Apartamento  São Francisco Xavier        2      1       0    48
# 22579  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 0      1700.0       500.0  60.0
# 1      7000.0         NaN   NaN
# ...

# %% [markdown]
# ## Exporting Database

# %%
select_residentials.to_csv('files/aluguel_residencial.csv', sep = ';', index = False)

# %%
data_residentials = pd.read_csv('files/aluguel_residencial.csv', sep = ';')
data_residentials
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento          Vista Alegre        3      1       0    70
# ...            ...                   ...      ...    ...     ...   ...
# 22575  Apartamento                 Méier        2      0       0    70
# 22576    Quitinete                Centro        0      0       0    27
# 22577  Apartamento           Jacarepaguá        3      1       2    78
# 22578  Apartamento  São Francisco Xavier        2      1       0    48
# 22579  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 0      1700.0       500.0  60.0
# 1      7000.0         NaN   NaN
# ...

# %%
data_residentials = pd.read_csv('files/aluguel_residencial.csv', sep = ';')
data_residentials
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento          Vista Alegre        3      1       0    70
# ...            ...                   ...      ...    ...     ...   ...
# 22575  Apartamento                 Méier        2      0       0    70
# 22576    Quitinete                Centro        0      0       0    27
# 22577  Apartamento           Jacarepaguá        3      1       2    78
# 22578  Apartamento  São Francisco Xavier        2      1       0    48
# 22579  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 0      1700.0       500.0  60.0
# 1      7000.0         NaN   NaN
# ...
